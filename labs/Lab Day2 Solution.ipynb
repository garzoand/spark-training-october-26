# %% [markdown]
# # Spark Training Exercise Book Day 2

# %% [markdown]
# In this excercise you will process Apache HTTP access logs with Spark. Below you can see some sample lines from our test dataset.
#
# The security team let you know, they would like to see some statistics from this large volume of log files, for example which resource produced the most of the non 200 (OK) HTTP response codes. They also have a list of malicious IP address. They would like to see a report about the specific requests which are initiated from one of these IPs.
#
# It is up to you how to implement this use-case in Spark.

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *

sc = pyspark.SparkContext()
spark = SparkSession(sc)

# %%
# !head -n 5 data/apache_logs.txt
# Out:
# head: cannot open 'data/apache_logs.txt' for reading: No such file or directory

# %% [markdown]
# As you can see, the Apache access log file is not perfactly a CSV so we need some additional processing to be able to build a dataframe from this file. Here are some helper functions which can help you in extracting the relevant fields for this excercise. You can use the **process_access_log_line** function to process one access log line and get back the IP address, the date (in string), the hour (int), some header information like resource as well as the HTTP response code generated by the server.

# %%
import time
import datetime

def get_ip(s):
    return s.split(' ')[0]

def get_timestamp(str):
    s = str.find('[')
    l = str.find(']')
    ts_str = str[s + 1:l]
    #return long(ts)
    return ts_str

def get_header(str):
    s = str.find('"')
    l = str[s + 1:].find('"')
    header = str[s + 1:s + l + 1].split(' ')
    method = header[0] if len(header) > 0 else "malformed"
    resource = header[1] if len(header) > 1 else "malformed"
    protocol = header[2] if len(header) > 2 else "malformed"        
    return (method, resource, protocol)
    
def get_error_code(str):
    f = str.split(' ')
    if len(f) < 9:
        return 0
    try:
        code = int(f[8])
    except ValueError:
        code = 0
    return code

# input: raw access log from the RDD
# output: structured daa: full line -> (ip, ts, date, hour, method, resource, protocol, response code)
def process_access_log_line(log_line):
    header = get_header(log_line)
    ts_str = get_timestamp(log_line)
    date_str = "1980-01-01"
    hour = 12
    try:
        td = datetime.datetime.strptime(ts_str, "%d/%b/%Y:%H:%M:%S %z")
        date_str = '{}-{}-{}'.format(td.year, td.month, td.day)   
        hour = td.hour
    except ValueError:
        pass
    return (get_ip(log_line), ts_str, date_str, hour, header[0], header[1], header[2], get_error_code(log_line))

# %% [markdown]
# Not it is time to read up the **data/access_logs.txt** file and do some transformation to be able to create a dataframe and do some aggregation. We also provided you the schema what is matching with the output of the **process_access_log_line** method and can be used to create the dataframe.

# %%
access_log_schema = StructType([
            StructField('ip', StringType(), True),
            StructField('ts', StringType(), True),
            StructField('date', StringType(), True),
            StructField('hour', IntegerType(), True),
            StructField('method', StringType(), True),
            StructField('resource', StringType(), True),
            StructField('protocol', StringType(), True),
            StructField('response', IntegerType(), True)
        ])

# %%
# !pwd
# Out:
# /home/andras/git

# %%
# Your code comes here

# Step 1: read the data to a RDD
rdd = sc.textFile('spark-training-october-20/data/apache_logs.txt')

# Step 2: transoform the lines of RDD to a "structured" format
#   you can use the process_access_log_line function for the transformation
rdd = rdd.filter(lambda line: len(line) > 0) \
    .map(process_access_log_line)

# Step 3: create the dataframe
df = spark.createDataFrame(rdd, access_log_schema)
df.show()
# Out:
# +---------------+--------------------+----------+----+------+--------------------+--------+--------+
# |             ip|                  ts|      date|hour|method|            resource|protocol|response|
# +---------------+--------------------+----------+----+------+--------------------+--------+--------+
# |109.169.248.247|12/Dec/2015:18:25...|2015-12-12|  18|   GET|     /administrator/|HTTP/1.1|     200|
# |109.169.248.247|12/Dec/2015:18:25...|2015-12-12|  18|  POST|/administrator/in...|HTTP/1.1|     200|
# |    46.72.177.4|12/Dec/2015:18:31...|2015-12-12|  18|   GET|     /administrator/|HTTP/1.1|     200|
# |    46.72.177.4|12/Dec/2015:18:31...|2015-12-12|  18|  POST|/administrator/in...|HTTP/1.1|     200|
# | 83.167.113.100|12/Dec/2015:18:31...|2015-12-12|  18|   GET|     /administrator/|HTTP/1.1|     200|
# | 83.167.113.100|12/Dec/2015:18:31...|2015-12-12|  18|  POST|/administrator/in...|HTTP/1.1|     200|
# |   95.29.198.15|12/Dec/2015:18:32...|2015-12-12|  18|   GET|     /administrator/|HTTP/1.1|     200|
# |   95.29.198.15|12/Dec/2015:18:32...|2015-12-12|  18|  POST|/administrator/in...|HTTP/1.1|     200|
# |  109.184.11.34|12/Dec/2015:18:32...|2015-12-12|  18|   GET|     /administrator/|HTTP/1.1|     200|
# |  109.184.11.34|12/Dec/2015:18:32...|2015-12-12|  18|  POST|/administrator/in...|HTTP/1.1|     200|
# |   91.227.29.79|12/Dec/2015:18:33...|2015-12-12|  18|   GET|     /administrator/|HTTP/1.1|     200|
# |   91.227.29.79|12/Dec/2015:18:33...|2015-12-12|  18|  POST|/administrator/in...|HTTP/1.1|     200|
# |  90.154.66.233|12/Dec/2015:18:36...|2015-12-12|  18|   GET|     /administrator/|HTTP/1.1|     200|
# |  90.154.66.233|12/Dec/2015:18:36...|2015-12-12|  18|  POST|/administrator/in...|HTTP/1.1|     200|
# |  95.140.24.131|12/Dec/2015:18:38...|2015-12-12|  18|   GET|     /administrator/|HTTP/1.1|     200|
# |  95.140.24.131|12/Dec/2015:18:38...|2015-12-12|  18|  POST|/administrator/in...|HTTP/1.1|     200|
# |  95.188.245.16|12/Dec/2015:18:38...|2015-12-12|  18|   GET|     /administrator/|HTTP/1.1|     200|
# |  95.188.245.16|12/Dec/2015:18:38...|2015-12-12|  18|  POST|/administrator/in...|HTTP/1.1|     200|
# |  46.72.213.133|12/Dec/2015:18:39...|2015-12-12|  18|   GET|     /administrator/|HTTP/1.1|     200|
# |  46.72.213.133|12/Dec/2015:18:39...|2015-12-12|  18|  POST|/administrator/in...|HTTP/1.1|     200|
# +---------------+--------------------+----------+----+------+--------------------+--------+--------+
# only showing top 20 rows

# %%
def generator(line):
    s = line.split(' ')
    for words in s:
        yield words
        
for i in generator('sadas sada sd as dasd'):
    print(i)
    
        
#sc.textFile('data/apache_logs.txt').flatMap(generator).take(100)
# Out:
# sadas
# sada
# sd
# as
# dasd

# %% [markdown]
# The security team would like to see the top 10 resources which generates the highest number of error (not 200) response codes. They would like to see this information on hourly basis. The security team would like to store this information on a shared distributed data storage (like S3) where they effectively can query this information. Most of the queries are filtered for one specific day.

# %%
# Your code comes here
df.createOrReplaceTempView('access_log')
df_res = spark.sql("""
SELECT date, hour, resource, count(1) as cnt
FROM access_log
WHERE response != 200
GROUP BY date, hour, resource
ORDER BY cnt DESC
LIMIT 10;
""")
df_res.show()

# Pythonic way, homework!
# Out:
# +----------+----+--------------------+---+
# |      date|hour|            resource|cnt|
# +----------+----+--------------------+---+
# | 2016-1-14|  20|/templates/_syste...| 63|
# | 2016-2-11|   0|/apache-log/acces...| 57|
# |  2016-1-1|  21|/templates/_syste...| 35|
# |  2016-2-8|   9|/templates/_syste...| 31|
# |  2016-1-6|  19|/templates/_syste...| 29|
# | 2016-1-15|  20|/templates/_syste...| 22|
# |2015-12-20|  18|/templates/_syste...| 22|
# |2015-12-20|  12|/apache-log/acces...| 20|
# | 2016-1-21|  13|      /administrator| 19|
# | 2016-1-14|   8|/templates/_syste...| 19|
# +----------+----+--------------------+---+

# %%
df_res.write \
    .format('parquet') \
    .mode('overwrite') \
    .save('access_log_report')

# %%
# !ls access_log_report
# Out:
# _SUCCESS  part-00000-f2fb1794-8cfd-459b-a47f-fc087239531e-c000.snappy.parquet

# %%
df_back = spark.read.format('parquet').load('access_log_report')
df_back.show()
# Out:
# +----------+----+--------------------+---+
# |      date|hour|            resource|cnt|
# +----------+----+--------------------+---+
# | 2016-1-14|  20|/templates/_syste...| 63|
# | 2016-2-11|   0|/apache-log/acces...| 57|
# |  2016-1-1|  21|/templates/_syste...| 35|
# |  2016-2-8|   9|/templates/_syste...| 31|
# |  2016-1-6|  19|/templates/_syste...| 29|
# | 2016-1-15|  20|/templates/_syste...| 22|
# |2015-12-20|  18|/templates/_syste...| 22|
# |2015-12-20|  12|/apache-log/acces...| 20|
# | 2016-1-21|  13|      /administrator| 19|
# | 2016-1-14|   8|/templates/_syste...| 19|
# +----------+----+--------------------+---+

# %%
df_res.write \
    .format('csv') \
    .option('header', 'true') \
    .mode('overwrite') \
    .partitionBy('date') \
    .save('access_log_report')

# %%
# !cat access_log_report/date=2016-1-6/part-00000-e0f6ca24-c133-42b4-85ba-e846f5f705d1.c000.csv
# Out:
# hour,resource,cnt
# 19,/templates/_system/css/general.css,29

# %%
df_res.write \
    .format('csv') \
    .option('header', 'true') \
    .mode('overwrite') \
    .bucketBy(6, 'resource') \
    .saveAsTable('access_log_report')
# .save('access_log_report')

# %%
# !ls spark-warehouse/access_log_report
# Out:
# _SUCCESS
# part-00000-4ad4f328-cf26-4fe9-9e7f-51a0383e935e_00000.c000.csv
# part-00000-4ad4f328-cf26-4fe9-9e7f-51a0383e935e_00001.c000.csv
# part-00000-4ad4f328-cf26-4fe9-9e7f-51a0383e935e_00003.c000.csv
# part-00000-4ad4f328-cf26-4fe9-9e7f-51a0383e935e_00004.c000.csv

# %%
print(df.rdd.getNumPartitions())
df = df.coalesce(1)
print(df.rdd.getNumPartitions())
# Out:
# 2
# 1

# %%
df = df.repartition(6)
df.write.format('csv').mode('overwrite').save('access_log_report')

# %%
# !ls access_log_report
# Out:
# _SUCCESS
# part-00000-413ad56e-01d3-4a66-b7b5-8fdf7dfdb0da-c000.csv
# part-00001-413ad56e-01d3-4a66-b7b5-8fdf7dfdb0da-c000.csv
# part-00002-413ad56e-01d3-4a66-b7b5-8fdf7dfdb0da-c000.csv
# part-00003-413ad56e-01d3-4a66-b7b5-8fdf7dfdb0da-c000.csv
# part-00004-413ad56e-01d3-4a66-b7b5-8fdf7dfdb0da-c000.csv
# part-00005-413ad56e-01d3-4a66-b7b5-8fdf7dfdb0da-c000.csv

# %%
df = df.repartition(100, 'hour')
print(df.rdd.getNumPartitions())
df.rdd.glom().take(4)
# Out:
# 100
# [[],
#  [],
#  [Row(ip='185.31.167.111', ts='13/Dec/2015:04:01:06 +0100', date='2015-12-13', hour=4, method='GET', resource='/administrator/', protocol='HTTP/1.1', response=200),
#   Row(ip='185.31.167.111', ts='13/Dec/2015:04:01:06 +0100', date='2015-12-13', hour=4, method='POST', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='31.134.53.96', ts='13/Dec/2015:04:08:50 +0100', date='2015-12-13', hour=4, method='GET', resource='/apache-log/access.log', protocol='HTTP/1.1', response=200),
#   Row(ip='46.44.5.179', ts='13/Dec/2015:04:10:24 +0100', date='2015-12-13', hour=4, method='GET', resource='/administrator/', protocol='HTTP/1.1', response=200),
#   Row(ip='46.44.5.179', ts='13/Dec/2015:04:10:24 +0100', date='2015-12-13', hour=4, method='POST', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='178.204.13.65', ts='13/Dec/2015:04:10:50 +0100', date='2015-12-13', hour=4, method='GET', resource='/administrator/', protocol='HTTP/1.1', response=200),
#   Row(ip='178.204.13.65', ts='13/Dec/2015:04:10:50 +0100', date='2015-12-13', hour=4, method='POST', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='109.188.126.7', ts='13/Dec/2015:04:12:42 +0100', date='2015-12-13', hour=4, method='GET', resource='/administrator/', protocol='HTTP/1.1', response=200),
#   Row(ip='109.188.126.7', ts='13/Dec/2015:04:12:42 +0100', date='2015-12-13', hour=4, method='POST', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='177.193.76.80', ts='13/Dec/2015:04:14:49 +0100', date='2015-12-13', hour=4, method='GET', resource='/administrator/', protocol='HTTP/1.1', response=200),
#   Row(ip='177.193.76.80', ts='13/Dec/2015:04:14:50 +0100', date='2015-12-13', hour=4, method='POST', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip
hour=4, method='GET', resource='/', protocol='HTTP/1.1', response=200),
#   Row(ip='188.138.9.49', ts='20/Dec/2015:04:06:41 +0100', date='2015-12-20', hour=4, method='POST', resource='/libraries/joomla/exporter.php', protocol='HTTP/1.1', response=404),
#   Row(ip='157.55.39.90', ts='20/Dec/2015:04:16:11 +0100', date='2015-12-20', hour=4, method='GET', resource='/robots.txt', protocol='HTTP/1.1', response=200),
#   Row(ip='31.132.176.94', ts='21/Dec/2015:04:00:34 +0100', date='2015-12-21', hour=4, method='GET', resource='/apache-log/access.log', protocol='HTTP/1.1', response=200),
#   Row(ip='31.132.176.94', ts='21/Dec/2015:04:00:35 +0100', date='2015-12-21', hour=4, method='GET', resource='/favicon.ico', protocol='HTTP/1.1', response=404),
#   Row(ip='31.132.176.94', ts='21/Dec/2015:04:03:35 +0100', date='2015-12-21', hour=4, method='GET', resource='/apache-log/access.log', protocol='HTTP/1.1', response=200),
#   Row(ip='146.0.72.80', ts='21/Dec/2015:04:30:40 +0100', date='2015-12-21', hour=4, method='GET', resource='/cfg.php', protocol='HTTP/1.1', response=404),
#   Row(ip='66.249.69.104', ts='21/Dec/2015:04:41:33 +0100', date='2015-12-21', hour=4, method='GET', resource='/index.php?option=com_phocagallery&view=category&id=2%3Awinterfotos&Itemid=53&limitstart=20', protocol='HTTP/1.1', response=200),
#   Row(ip='62.93.172.253', ts='22/Dec/2015:04:03:01 +0100', date='2015-12-22', hour=4, method='GET', resource='/administrator/index.php/', protocol='HTTP/1.1', response=200),
#   Row(ip='62.93.172.241', ts='22/Dec/2015:04:03:05 +0100', date='2015-12-22', hour=4, method='POST', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='80.29.9.107', ts='22/Dec/2015:04:43:17 +0100', date='2015-12-22', hour=4, method='GET', resource='/administrator/index.php/', protocol='HTTP/1.1', response=200),
#   Row(ip='88.19.157.146', ts='22/Dec/2015:04:43:27 +0100', date='2015-12-22', hour=4, method='POST', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='62.138.0.25', ts='23/Dec/2015:04:04:34 +0100', date='2015-12-23', hour=4, method='GET', resource='/robots.txt', protocol='HTTP/1.1', response=200),
#   Row(ip='88.19.157.146', ts='23/Dec/2015:04:06:09 +0100', date='2015-12-23', hour=4, method='GET', resource='/administrator/index.php/', protocol='HTTP/1.1', response=200),
#   Row(ip='79.153.243.16', ts='23/Dec/2015:04:06:09 +0100', date='2015-12-23', hour=4, method='POST', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='66.249.64.172', ts='23/Dec/2015:04:27:47 +0100', date='2015-12-23', hour=4, method='GET', resource='/index.php?option=com_content&view=article&id=46&Itemid=54', protocol='HTTP/1.1', response=200),
#   Row(ip='37.1.206.196', ts='23/Dec/2015:04:28:33 +0100', date='2015-12-23', hour=4, method='GET', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='37.1.206.196', ts='23/Dec/2015:04:28:33 +0100', date='2015-12-23', hour=4, method='POST', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='37.1.206.196', ts='23/Dec/2015:04:28:33 +0100', date='2015-12-23', hour=4, method='GET', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='151.236.23.54', ts='23/Dec/2015:04:31:46 +0100', date='2015-12-23', hour=4, method='GET', resource='/administrator/', protocol='HTTP/1.1', response=200),
#   Row(ip='151.236.23.54', ts='23/Dec/2015:04:31:46 +0100', date='2015-12-23', hour=4, method='POST', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='83.57.237.241', ts='23/Dec/2015:04:40:54 +0100', date='2015-12-23', hour=4, method='GET', resource='/administrator/index.php/', protocol='HTTP/1.1', response=200),
#   Row(ip='83.57.237.241', ts='23/Dec/2015:04:40:55 +0100', date='2015-12-23', hour=4, method='POST', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='207.46.13.89', ts='23/Dec/2015:04:49:21 +0100', date='2015-12-23', hour=4, method='GET', resource='/index.php?option=com_content&view=article&id=49&Itemid=55', protocol='HTTP/1.1', response=200),
#   Row(ip='23.229.34.189', ts='24/Dec/2015:04:17:24 +0100', date='2015-12-24', hour=4, method='GET', resource='/apache-log/access.log', protocol='HTTP/1.1', response=200),
#   Row(ip
hour=4, method='GET', resource='/robots.txt', protocol='HTTP/1.1', response=200),
#   Row(ip='66.249.75.142', ts='28/Dec/2015:04:44:53 +0100', date='2015-12-28', hour=4, method='GET', resource='/', protocol='HTTP/1.1', response=200),
#   Row(ip='37.1.206.196', ts='28/Dec/2015:04:56:59 +0100', date='2015-12-28', hour=4, method='GET', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='37.1.206.196', ts='28/Dec/2015:04:56:59 +0100', date='2015-12-28', hour=4, method='POST', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='37.1.206.196', ts='28/Dec/2015:04:56:59 +0100', date='2015-12-28', hour=4, method='GET', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='157.55.39.207', ts='29/Dec/2015:04:41:22 +0100', date='2015-12-29', hour=4, method='GET', resource='/robots.txt', protocol='HTTP/1.1', response=200),
#   Row(ip='40.77.167.79', ts='02/Jan/2016:04:04:57 +0100', date='2016-1-2', hour=4, method='GET', resource='/robots.txt', protocol='HTTP/1.1', response=200),
#   Row(ip='40.77.167.79', ts='02/Jan/2016:04:05:10 +0100', date='2016-1-2', hour=4, method='GET', resource='/icons/back.gif', protocol='HTTP/1.1', response=404),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:08:51 +0100', date='2016-1-2', hour=4, method='GET', resource='/', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:08:52 +0100', date='2016-1-2', hour=4, method='GET', resource='/index.php?format=feed&amp;type=rss', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:08:53 +0100', date='2016-1-2', hour=4, method='GET', resource='/index.php?format=feed&amp;type=atom', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:08:53 +0100', date='2016-1-2', hour=4, method='GET', resource='/modules/mod_bowslideshow/tmpl/css/bowslideshow.css', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:08:53 +0100', date='2016-1-2', hour=4, method='GET', resource='/templates/_system/css/general.css', protocol='HTTP/1.0', response=404),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:08:54 +0100', date='2016-1-2', hour=4, method='GET', resource='/templates/jp_hotel/css/template.css', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:08:54 +0100', date='2016-1-2', hour=4, method='GET', resource='/templates/jp_hotel/css/layout.css', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:08:54 +0100', date='2016-1-2', hour=4, method='GET', resource='/templates/jp_hotel/css/menu.css', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:08:55 +0100', date='2016-1-2', hour=4, method='GET', resource='/templates/jp_hotel/css/suckerfish.css', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:08:55 +0100', date='2016-1-2', hour=4, method='GET', resource='/index.php?option=com_content&amp;view=article&amp;id=49&amp;Itemid=55', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:08:56 +0100', date='2016-1-2', hour=4, method='GET', resource='/index.php?option=com_content&amp;view=article&amp;id=50&amp;Itemid=56', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:08:57 +0100', date='2016-1-2', hour=4, method='GET', resource='/index.php?option=com_phocagallery&amp;view=category&amp;id=1&amp;Itemid=53', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:08:58 +0100', date='2016-1-2', hour=4, method='GET', resource='/index.php?option=com_content&amp;view=article&amp;id=46&amp;Itemid=54', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:08:59 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/stories/raith/wohnung_1_web.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:08:59 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/stories/raith/wohnung_2_web.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:00 +0100', date='2016-1-2', hour=4, method='GET', resource='/index.php?option=com_phocagallery&amp;view=category&amp;id=4:ferienwohnung2&amp;Itemid=53', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:01 +0100', date='2016-1-2', hour=4, method='GET', resource='/components/com_phocagallery/assets/phocagallery.css', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:01 +0100', date='2016-1-2', hour=4, method='GET', resource='/media/system/css/modal.css', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:02 +0100', date='2016-1-2', hour=4, method='GET', resource='/components/com_phocagallery/assets/phocagalleryieall.css', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:02 +0100', date='2016-1-2', hour=4, method='GET', resource='/index.php?option=com_phocagallery&amp;view=category&amp;id=3:almhuette-raith&amp;Itemid=0', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:04 +0100', date='2016-1-2', hour=4, method='GET', resource='/index.php?option=com_phocagallery&amp;view=category&amp;id=2:winterfotos&amp;Itemid=0', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:05 +0100', date='2016-1-2', hour=4, method='GET', resource='/index.php?option=com_phocagallery&amp;view=category&amp;id=4:ferienwohnung2&amp;Itemid=0', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:06 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_almhuette_raith.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:07 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_aussicht.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:08 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_garage.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:08 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_grillplatz.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:09 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_jaegerzaun_gr.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:09 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_terasse.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:10 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_wohnraum.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:10 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_zimmer.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:11 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_almhuette_raith_001.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:13 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_almhuette_raith_002.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:13 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_almhuette_raith_003.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:14 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_almhuette_raith_004.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:14 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_almhuette_raith_005.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:15 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_almhuette_raith_006.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:16 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_almhuette_raith_007.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:16 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_almhuette_raith_008.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:17 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_almhuette_raith_009.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:17 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_almhuette_raith_010.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:18 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_almhuette_raith_011.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:19 +0100', date='2016-1-2', hour=4, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_almhuette_raith_012.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:20 +0100', date='2016-1-2', hour=4, method='GET', resource='/wp-login.php', protocol='HTTP/1.0', response=404),
#   Row(ip='35.9.18.28', ts='02/Jan/2016:04:09:20 +0100', date='2016-1-2', hour=4, method='GET', resource='/administrator/index.php', protocol='HTTP/1.0', response=200),
#   Row(ip='77.41.95.134', ts='04/Jan/2016:04:01:36 +0100', date='2016-1-4', hour=4, method='GET', resource='/apache-log/access.log', protocol='HTTP/1.0', response=200),
#   Row(ip='74.143.193.83', ts='04/Jan/2016:04:18:19 +0100', date='2016-1-4', hour=4, method='GET', resource='/apache-log/access.log', protocol='HTTP/1.1', response=200),
#   Row(ip='66.249.64.202', ts='04/Jan/2016:04:23:50 +0100', date='2016-1-4', hour=4, method='GET', resource='/', protocol='HTTP/1.1', response=200),
#   Row(ip='180.76.15.147', ts='04/Jan/2016:04:41:32 +0100', date='2016-1-4', hour=4, method='GET', resource='/', protocol='HTTP/1.1', response=200),
#   Row(ip='46.143.231.6', ts='04/Jan/2016:04:44:38 +0100', date='2016-1-4', hour=4, method='GET', resource='/apache-log/access.log', protocol='HTTP/1.1', response=200),
#   Row(ip='86.105.81.139', ts='04/Jan/2016:04:45:30 +0100', date='2016-1-4', hour=4, method='GET', resource='/wp-login.php?action=register', protocol='HTTP/1.1', response=404),
#   Row(ip='87.145.212.196', ts='05/Jan/2016:04:19:40 +0100', date='2016-1-5', hour=4, method='GET', resource='/', protocol='HTTP/1.1', response=200),
#   Row(ip='180.76.15.158', ts='05/Jan/2016:04:48:54 +0100', date='2016-1-5', hour=4, method='GET', resource='/apache-log/access.log', protocol='HTTP/1.1', response=200),
#   Row(ip='66.249.69.120', ts='05/Jan/2016:04:51:37 +0100', date='2016-1-5', hour=4, method='GET', resource='/index.php?option=com_content&view=article&id=46&Itemid=54', protocol='HTTP/1.1', response=200),
#   Row(ip='77.75.77.95', ts='06/Jan/2016:04:24:08 +0100', date='2016-1-6', hour=4, method='GET', resource='/robots.txt', protocol='HTTP/1.1', response=200),
#   Row(ip='207.46.13.54', ts='06/Jan/2016:04:24:09 +0100', date='2016-1-6', hour=4, method='GET', resource='/', protocol='HTTP/1.1', response=200),
#   Row(ip='178.137.161.162', ts='06/Jan/2016:04:52:29 +0100', date='2016-1-6', hour=4, method='GET', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='178.137.161.162', ts='06/Jan/2016:04:52:30 +0100', date='2016-1-6', hour=4, method='POST', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='178.137.161.162', ts='06/Jan/2016:04:52:30 +0100', date='2016-1-6', hour=4, method='GET', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='207.46.13.54', ts='07/Jan/2016:04:38:09 +0100', date='2016-1-7', hour=4, method='GET', resource='/robots.txt', protocol='HTTP/1.1', response=200),
#   Row(ip='207.46.13.54', ts='07/Jan/2016:04:38:51 +0100', date='2016-1-7', hour=4, method='GET', resource='/', protocol='HTTP/1.1', response=200),
#   Row(ip='207.46.13.165', ts='07/Jan/2016:04:40:13 +0100', date='2016-1-7', hour=4, method='GET', resource='/index.php?option=com_content&view=article&id=46&Itemid=54', protocol='HTTP/1.1', response=200),
#   Row(ip='157.55.39.99', ts='09/Jan/2016:04:06:33 +0100', date='2016-1-9', hour=4, method='GET', resource='/robots.txt', protocol='HTTP/1.1', response=200),
#   Row(ip='46.119.112.83', ts='09/Jan/2016:04:15:21 +0100', date='2016-1-9', hour=4, method='GET', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='46.119.112.83', ts='09/Jan/2016:04:15:21 +0100', date='2016-1-9', hour=4, method='POST', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
# ...
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:31 +0100', date='2016-1-19', hour=8, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_m_almhuette_raith_011.jpg', protocol='HTTP/1.1', response=200),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:31 +0100', date='2016-1-19', hour=8, method='GET', resource='/components/com_phocagallery/assets/js/shadowbox/src/lang/shadowbox-en.js', protocol='HTTP/1.1', response=200),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:31 +0100', date='2016-1-19', hour=8, method='GET', resource='/components/com_phocagallery/assets/js/shadowbox/src/player/shadowbox-img.js', protocol='HTTP/1.1', response=200),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:31 +0100', date='2016-1-19', hour=8, method='GET', resource='/components/com_phocagallery/assets/js/shadowbox/src/skin/classic/icons/close.png', protocol='HTTP/1.1', response=200),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:31 +0100', date='2016-1-19', hour=8, method='GET', resource='/components/com_phocagallery/assets/js/shadowbox/src/skin/classic/icons/next.png', protocol='HTTP/1.1', response=200),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:31 +0100', date='2016-1-19', hour=8, method='GET', resource='/components/com_phocagallery/assets/js/shadowbox/src/skin/classic/icons/play.png', protocol='HTTP/1.1', response=200),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:31 +0100', date='2016-1-19', hour=8, method='GET', resource='/components/com_phocagallery/assets/js/shadowbox/src/skin/classic/icons/pause.png', protocol='HTTP/1.1', response=200),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:31 +0100', date='2016-1-19', hour=8, method='GET', resource='/components/com_phocagallery/assets/js/shadowbox/src/skin/classic/icons/previous.png', protocol='HTTP/1.1', response=200),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:31 +0100', date='2016-1-19', hour=8, method='GET', resource='/components/com_phocagallery/assets/js/shadowbox/src/skin/classic/loading.gif', protocol='HTTP/1.1', response=304),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:31 +0100', date='2016-1-19', hour=8, method='GET', resource='/components/com_phocagallery/assets/images/shadow1.gif', protocol='HTTP/1.1', response=304),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:45 +0100', date='2016-1-19', hour=8, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_almhuette_raith_012.jpg', protocol='HTTP/1.1', response=304),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:45 +0100', date='2016-1-19', hour=8, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_almhuette_raith_010.jpg', protocol='HTTP/1.1', response=200),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:45 +0100', date='2016-1-19', hour=8, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_almhuette_raith_011.jpg', protocol='HTTP/1.1', response=200),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:48 +0100', date='2016-1-19', hour=8, method='GET', resource='/images/phocagallery/almhuette/thumbs/phoca_thumb_l_almhuette_raith.jpg', protocol='HTTP/1.1', response=304),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:52 +0100', date='2016-1-19', hour=8, method='GET', resource='/templates/_system/css/general.css', protocol='HTTP/1.1', response=404),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:57 +0100', date='2016-1-19', hour=8, method='GET', resource='/templates/_system/css/general.css', protocol='HTTP/1.1', response=404),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:59 +0100', date='2016-1-19', hour=8, method='GET', resource='/index.php?option=com_content&view=article&id=46&Itemid=54', protocol='HTTP/1.1', response=200),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:59 +0100', date='2016-1-19', hour=8, method='GET', resource='/templates/_system/css/general.css', protocol='HTTP/1.1', response=404),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:59 +0100', date='2016-1-19', hour=8, method='GET', resource='/modules/mod_bowslideshow/tmpl/css/bowslideshow.css', protocol='HTTP/1.1', response=304),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:59 +0100', date='2016-1-19', hour=8, method='GET', resource='/templates/jp_hotel/css/suckerfish.css', protocol='HTTP/1.1', response=304),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:59 +0100', date='2016-1-19', hour=8, method='GET', resource='/templates/_system/css/general.css', protocol='HTTP/1.1', response=404),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:59 +0100', date='2016-1-19', hour=8, method='GET', resource='/templates/jp_hotel/css/menu.css', protocol='HTTP/1.1', response=304),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:44:59 +0100', date='2016-1-19', hour=8, method='GET', resource='/templates/jp_hotel/images/logo.jpg', protocol='HTTP/1.1', response=304),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:45:04 +0100', date='2016-1-19', hour=8, method='GET', resource='/templates/_system/css/general.css', protocol='HTTP/1.1', response=404),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:45:04 +0100', date='2016-1-19', hour=8, method='GET', resource='/templates/_system/css/general.css', protocol='HTTP/1.1', response=404),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:45:06 +0100', date='2016-1-19', hour=8, method='GET', resource='/', protocol='HTTP/1.1', response=200),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:45:06 +0100', date='2016-1-19', hour=8, method='GET', resource='/index.php?format=feed&amp;type=atom', protocol='HTTP/1.1', response=200),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:45:06 +0100', date='2016-1-19', hour=8, method='GET', resource='/index.php?format=feed&amp;type=rss', protocol='HTTP/1.1', response=200),
#   Row(ip='212.31.69.11', ts='19/Jan/2016:08:45:06 +0100', date='2016-1-19', hour=8, method='GET', resource='/templates/_system/css/general.css', protocol='HTTP/1.1', response=404),
#   Row(ip='207.46.13.8', ts='19/Jan/2016:08:52:32 +0100', date='2016-1-19', hour=8, method='GET', resource='/', protocol='HTTP/1.1', response=200),
#   Row(ip='85.158.137.195', ts='20/Jan/2016:08:39:27 +0100', date='2016-1-20', hour=8, method='GET', resource='/', protocol='HTTP/1.1', response=200),
#   Row(ip='85.158.137.195', ts='20/Jan/2016:08:39:27 +0100', date='2016-1-20', hour=8, method='GET', resource='/media/system/js/caption.js', protocol='HTTP/1.1', response=304),
#   Row(ip='85.158.137.195', ts='20/Jan/2016:08:39:27 +0100', date='2016-1-20', hour=8, method='GET', resource='/templates/_system/css/general.css', protocol='HTTP/1.1', response=404),
#   Row(ip='85.158.137.195', ts='20/Jan/2016:08:39:28 +0100', date='2016-1-20', hour=8, method='GET', resource='/templates/jp_hotel/images/content_heading.gif', protocol='HTTP/1.1', response=304),
#   Row(ip='85.158.137.195', ts='20/Jan/2016:08:39:28 +0100', date='2016-1-20', hour=8, method='GET', resource='/modules/mod_bowslideshow/tmpl/images/image_shadow.png', protocol='HTTP/1.1', response=304),
#   Row(ip='85.158.137.195', ts='20/Jan/2016:08:39:28 +0100', date='2016-1-20', hour=8, method='GET', resource='/templates/jp_hotel/images/module_heading.gif', protocol='HTTP/1.1', response=304),
#   Row(ip='85.158.137.195', ts='20/Jan/2016:08:40:55 +0100', date='2016-1-20', hour=8, method='GET', resource='/index.php?option=com_content&view=article&id=46&Itemid=54', protocol='HTTP/1.1', response=200),
#   Row(ip='85.158.137.195', ts='20/Jan/2016:08:40:55 +0100', date='2016-1-20', hour=8, method='GET', resource='/media/system/js/caption.js', protocol='HTTP/1.1', response=304),
#   Row(ip='85.158.137.195', ts='20/Jan/2016:08:40:55 +0100', date='2016-1-20', hour=8, method='GET', resource='/templates/_system/css/general.css', protocol='HTTP/1.1', response=404),
#   Row(ip='85.158.137.195', ts='20/Jan/2016:08:40:55 +0100', date='2016-1-20', hour=8, method='GET', resource='/modules/mod_bowslideshow/tmpl/images/image_shadow.png', protocol='HTTP/1.1', response=304),
#   Row(ip='85.158.137.195', ts='20/Jan/2016:08:40:55 +0100', date='2016-1-20', hour=8, method='GET', resource='/templates/jp_hotel/images/content_heading.gif', protocol='HTTP/1.1', response=304),
#   Row(ip='85.158.137.195', ts='20/Jan/2016:08:40:55 +0100', date='2016-1-20', hour=8, method='GET', resource='/templates/jp_hotel/images/module_heading.gif', protocol='HTTP/1.1', response=304),
#   Row(ip='85.158.137.195', ts='20/Jan/2016:08:40:58 +0100', date='2016-1-20', hour=8, method='GET', resource='/', protocol='HTTP/1.1', response=200),
#   Row(ip='85.158.137.195', ts='20/Jan/2016:08:40:58 +0100', date='2016-1-20', hour=8, method='GET', resource='/templates/_system/css/general.css', protocol='HTTP/1.1', response=404),
#   Row(ip='85.158.137.195', ts='20/Jan/2016:08:40:58 +0100', date='2016-1-20', hour=8, method='GET', resource='/media/system/js/caption.js', protocol='HTTP/1.1', response=304),
#   Row(ip='85.158.137.195', ts='20/Jan/2016:08:40:58 +0100', date='2016-1-20', hour=8, method='GET', resource='/templates/jp_hotel/images/content_heading.gif', protocol='HTTP/1.1', response=304),
#   Row(ip='85.158.137.195', ts='20/Jan/2016:08:40:58 +0100', date='2016-1-20', hour=8, method='GET', resource='/modules/mod_bowslideshow/tmpl/images/image_shadow.png', protocol='HTTP/1.1', response=304),
#   Row(ip='85.158.137.195', ts='20/Jan/2016:08:40:58 +0100', date='2016-1-20', hour=8, method='GET', resource='/templates/jp_hotel/images/module_heading.gif', protocol='HTTP/1.1', response=304),
#   Row(ip='207.241.237.226', ts='20/Jan/2016:08:50:02 +0100', date='2016-1-20', hour=8, method='GET', resource='/robots.txt', protocol='HTTP/1.0', response=200),
#   Row(ip='207.241.237.226', ts='20/Jan/2016:08:50:06 +0100', date='2016-1-20', hour=8, method='GET', resource='/images/stories/raith/garage.jpg', protocol='HTTP/1.0', response=200),
#   Row(ip='157.55.39.25', ts='20/Jan/2016:08:54:05 +0100', date='2016-1-20', hour=8, method='GET', resource='/index.php?option=com_phocagallery&view=category&id=4:ferienwohnung2&Itemid=53', protocol='HTTP/1.1', response=200),
#   Row(ip='157.55.39.25', ts='20/Jan/2016:08:54:05 +0100', date='2016-1-20', hour=8, method='GET', resource='/index.php?option=com_content&view=article&id=50&Itemid=56', protocol='HTTP/1.1', response=200),
#   Row(ip='66.151.86.252', ts='21/Jan/2016:08:27:24 +0100', date='2016-1-21', hour=8, method='GET', resource='/apache-log/access.log', protocol='HTTP/1.0', response=200),
#   Row(ip='66.151.86.252', ts='21/Jan/2016:08:27:28 +0100', date='2016-1-21', hour=8, method='GET', resource='/templates/jp_hotel/css/template.css', protocol='HTTP/1.1', response=200),
#   Row(ip='46.229.164.100', ts='21/Jan/2016:08:52:33 +0100', date='2016-1-21', hour=8, method='GET', resource='/robots.txt', protocol='HTTP/1.1', response=200),
#   Row(ip='46.74.52.157', ts='22/Jan/2016:08:42:22 +0100', date='2016-1-22', hour=8, method='GET', resource='/templates/_system/css/general.css', protocol='HTTP/1.1', response=404),
#   Row(ip='46.74.52.157', ts='22/Jan/2016:08:42:22 +0100', date='2016-1-22', hour=8, method='GET', resource='/images/stories/raith/wohnung_2_web.jpg', protocol='HTTP/1.1', response=200),
#   Row(ip='46.148.18.74', ts='23/Jan/2016:08:35:02 +0100', date='2016-1-23', hour=8, method='GET', resource='/', protocol='HTTP/1.1', response=200),
#   Row(ip='91.200.12.22', ts='23/Jan/2016:08:40:11 +0100', date='2016-1-23', hour=8, method='GET', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='91.200.12.22', ts='23/Jan/2016:08:40:12 +0100', date='2016-1-23', hour=8, method='POST', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   Row(ip='157.55.39.153', ts='24/Jan/2016:08:10:22 +0100', date='2016-1-24', hour=8, method='GET', resource='/apache-log/error.log.83.gz', protocol='HTTP/1.1', response=404),
#   Row(ip='68.180.230.251', ts='25/Jan/2016:08:00:46 +0100', date='2016-1-25', hour=8, method='GET', resource='/robots.txt', protocol='HTTP/1.1', response=200),
#   Row(ip='68.180.230.251', ts='25/Jan/2016:08:00:47 +0100', date='2016-1-25', hour=8, method='GET', resource='/index.php?format=feed&type=rss', protocol='HTTP/1.1', response=200),
#   Row(ip='66.249.64.202', ts='25/Jan/2016:08:28:43 +0100', date='2016-1-25', hour=8, method='GET', resource='/robots.txt', protocol='HTTP/1.1', response=200),
#   Row(ip='66.249.64.207', ts='25/Jan/2016:08:28:44 +0100', date='2016-1-25', hour=8, method='GET', resource='/', protocol='HTTP/1.1', response=200),
#   Row(ip='40.77.167.85', ts='26/Jan/2016:08:01:38 +0100', date='2016-1-26', hour=8, method='GET', resource='/', protocol='HTTP/1.1', response=200),
#   Row(ip='40.77.167.91', ts='26/Jan/2016:08:01:46 +0100', date='2016-1-26', hour=8, method='GET', resource='/robots.txt', protocol='HTTP/1.1', response=200),
#   Row(ip='40.77.167.91', ts='26/Jan/2016:08:01:46 +0100', date='2016-1-26', hour=8, method='GET', resource='/robots.txt', protocol='HTTP/1.1', response=200),
#   Row(ip='40.77.167.91', ts='26/Jan/2016:08:01:46 +0100', date='2016-1-26', hour=8, method='GET', resource='/robots.txt', protocol='HTTP/1.1', response=200),
#   Row(ip='40.77.167.91', ts='26/Jan/2016:08:01:46 +0100', date='2016-1-26', hour=8, method='GET', resource='/robots.txt', protocol='HTTP/1.1', response=200),
#   Row(ip='40.77.167.91', ts='26/Jan/2016:08:01:46 +0100', date='2016-1-26', hour=8, method='GET', resource='/robots.txt', protocol='HTTP/1.1', response=200),
#   Row(ip='40.77.167.91', ts='26/Jan/2016:08:01:47 +0100', date='2016-1-26', hour=8, method='GET', resource='/robots.txt', protocol='HTTP/1.1', response=200),
#   Row(ip='40.77.167.91', ts='26/Jan/2016:08:01:47 +0100', date='2016-1-26', hour=8, method='GET', resource='/robots.txt', protocol='HTTP/1.1', response=200),
#   Row(ip='40.77.167.91', ts='26/Jan/2016:08:01:47 +0100', date='2016-1-26', hour=8, method='GET', resource='/robots.txt', protocol='HTTP/1.1', response=200),
#   Row(ip='40.77.167.92', ts='26/Jan/2016:08:35:56 +0100', date='2016-1-26', hour=8, method='GET', resource='/apache-log/error.log.53.gz', protocol='HTTP/1.1', response=404),
#   Row(ip='192.81.210.167', ts='27/Jan/2016:08:42:13 +0100', date='2016-1-27', hour=8, method='GET', resource='/', protocol='HTTP/1.0', response=200),
#   Row(ip='192.81.210.167', ts='27/Jan/2016:08:42:13 +0100', date='2016-1-27', hour=8, method='POST', resource='/', protocol='HTTP/1.0', response=200),
#   Row(ip='40.77.167.56', ts='28/Jan/2016:08:09:38 +0100', date='2016-1-28', hour=8, method='GET', resource='/index.php?option=com_phocagallery&view=category&id=1&Itemid=53&limitstart=20', protocol='HTTP/1.1', response=200),
#   Row(ip='77.119.131.250', ts='28/Jan/2016:08:41:14 +0100', date='2016-1-28', hour=8, method='GET', resource='/', protocol='HTTP/1.1', response=200),
#   Row(ip='77.119.131.250', ts='28/Jan/2016:08:41:14 +0100', date='2016-1-28', hour=8, method='GET', resource='/templates/_system/css/general.css', protocol='HTTP/1.1', response=404),
#   Row(ip='77.119.131.250', ts='28/Jan/2016:08:41:16 +0100', date='2016-1-28', hour=8, method='GET', resource='/favicon.ico', protocol='HTTP/1.1', response=404),
#   Row(ip='77.119.131.250', ts='28/Jan/2016:08:41:29 +0100', date='2016-1-28', hour=8, method='GET', resource='/', protocol='HTTP/1.1', response=200),
#   Row(ip='77.119.131.250', ts='28/Jan/2016:08:42:14 +0100', date='2016-1-28', hour=8, method='GET', resource='/', protocol='HTTP/1.1', response=200),
#   Row(ip='77.119.131.250', ts='28/Jan/2016:08:42:14 +0100', date='2016-1-28', hour=8, method='GET', resource='/templates/_system/css/general.css', protocol='HTTP/1.1', response=404),
#   Row(ip='77.119.131.250', ts='28/Jan/2016:08:42:15 +0100', date='2016-1-28', hour=8, method='GET', resource='/favicon.ico', protocol='HTTP/1.1', response=404),
#   Row(ip='77.119.131.250', ts='28/Jan/2016:08:42:25 +0100', date='2016-1-28', hour=8, method='GET', resource='/', protocol='HTTP/1.1', response=200),
#   Row(ip='37.115.33.169', ts='29/Jan/2016:08:36:12 +0100', date='2016-1-29', hour=8, method='GET', resource='/administrator/index.php', protocol='HTTP/1.1', response=200),
#   ...]]

# %% [markdown]
# The security team also provided a list of malicious IP address. Your task is to count how many requests coming from each malicous IP address in each hour. You will find the IP list under the **data/ip-list.txt**

# %%
# !head -10 data/ip-list.txt
# Out:
# Malicious IP address:  109.106.142.176
# Malicious IP address:  109.184.11.34
# Malicious IP address:  128.72.82.254
# Malicious IP address:  130.255.13.57
# Malicious IP address:  176.194.74.20
# Malicious IP address:  176.214.240.8
# Malicious IP address:  177.201.52.125
# Malicious IP address:  178.35.29.219
# Malicious IP address:  195.8.51.14
# Malicious IP address:  2.86.149.141

# %%
def process_ip_line(line):
    s = line.split(':')[1].replace(' ', '')
    return s

#process_ip_line('Malicious IP address:  109.106.142.176')

# your code comes here
rdd = sc.textFile('spark-training-october-20/data/ip-list.txt')
rdd = rdd.map(process_ip_line)
print(rdd.take(10))

df_ip = rdd.toDF(StringType())
df_ip.show()
# Out:
# ['109.106.142.176', '109.184.11.34', '128.72.82.254', '130.255.13.57', '176.194.74.20', '176.214.240.8', '177.201.52.125', '178.35.29.219', '195.8.51.14', '2.86.149.141']
# +---------------+
# |          value|
# +---------------+
# |109.106.142.176|
# |  109.184.11.34|
# |  128.72.82.254|
# |  130.255.13.57|
# |  176.194.74.20|
# |  176.214.240.8|
# | 177.201.52.125|
# |  178.35.29.219|
# |    195.8.51.14|
# |   2.86.149.141|
# |    2.93.22.237|
# |   204.44.90.14|
# |  206.59.253.65|
# | 213.24.132.190|
# |   37.1.206.196|
# | 37.113.244.223|
# | 46.146.101.241|
# |  46.166.75.133|
# |   46.211.46.18|
# |   5.138.36.198|
# +---------------+
# only showing top 20 rows

# %%
def process_ip_line(line):
    s = line.split(':')[1].replace(' ', '')
    return (s,)

#process_ip_line('Malicious IP address:  109.106.142.176')

# your code comes here
rdd = sc.textFile('spark-training-october-20/data/ip-list.txt')
rdd = rdd.map(process_ip_line)
df_ip = rdd.toDF(['malicious_ip'])
df_ip.show()
# Out:
# +---------------+
# |   malicious_ip|
# +---------------+
# |109.106.142.176|
# |  109.184.11.34|
# |  128.72.82.254|
# |  130.255.13.57|
# |  176.194.74.20|
# |  176.214.240.8|
# | 177.201.52.125|
# |  178.35.29.219|
# |    195.8.51.14|
# |   2.86.149.141|
# |    2.93.22.237|
# |   204.44.90.14|
# |  206.59.253.65|
# | 213.24.132.190|
# |   37.1.206.196|
# | 37.113.244.223|
# | 46.146.101.241|
# |  46.166.75.133|
# |   46.211.46.18|
# |   5.138.36.198|
# +---------------+
# only showing top 20 rows

# %%
# 
# df.join(other_df, df.key1 == other_df.key2, 'inner')
# df.join(other_df.hint('broadcast'), df.key1 == other_df.key2, 'inner')
#
# df.explain()
df_joined = df.join(df_ip.hint('broadcast'), df.ip == df_ip.malicious_ip, 'inner')
df_joined.explain()
# Out:
# == Physical Plan ==
# *(2) BroadcastHashJoin [ip#191], [malicious_ip#301], Inner, BuildRight
# :- *(2) Filter isnotnull(ip#191)
# :  +- *(2) Scan ExistingRDD[ip#191,ts#192,date#193,hour#194,method#195,resource#196,protocol#197,response#198]
# +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, false])), [id=#334]
#    +- *(1) Filter isnotnull(malicious_ip#301)
#       +- *(1) Scan ExistingRDD[malicious_ip#301]
